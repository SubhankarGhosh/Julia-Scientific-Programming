# %%
using Plots

f(x) = 5 * x^2 + 3 * x - 20
plot(f, -10:10)

# %%
plot!(zero, -10, 10)

# %%
f(x) = -9*x^2 + 3*x + 6

using Plots
# Plot the function f

# %%
plot(f, -2:2)

# %%
plot(-2, 2, f)

# %%
plot(f, -2, 2)

# %%
plot(f)
