# %%
all(!isnumber, string(2))
# Out:
# false

# %%
all(isnumber, string(2))
# Out:
# true

# %%
?isnumber
# Out:
# search:
# ```
# isnumber(c::Char) -> Bool
# ```
#
# Tests whether a character is numeric. A character is classified as numeric if it belongs to the Unicode general category Number, i.e. a character whose category code begins with 'N'.
# isnumber

# %%
f(x) = 3 * x^2 + 6 * x - 9;
for x = -5:5    
  println("(",x, ", ", f(x), ")");
end
# Out:
# (-5, 36)
# (-4, 15)
# (-3, 0)
# (-2, -9)
# (-1, -12)
# (0, -9)
# (1, 0)
# (2, 15)
# (3, 36)
# (4, 63)
# (5, 96)

# %%
using Plots
plot(f, -4, 3) # plot f over [-4,4]
plot!(zero, -4, 3)

# %%
data = [1.6800483  -1.641695388; 
        0.501309281 -0.977697538; 
        1.528012113 0.52771122;
        1.70012253 1.711524991; 
        1.992493625 1.891000015;
        2.706075824 -0.463427794;
        2.994931927 -0.443566619;
        3.491852811 -1.275179133;
        3.501191722 -0.690499597;
        4.459924502 -5.516130799;
        4.936965851 -6.001703074;
        5.023289852 -8.36416901;
        5.04233698 -7.924477517;
        5.50739285 -10.77482371;
        5.568665171 -10.9171878];

# %%
x = data[:,1]
# Out:
# 15-element Array{Float64,1}:
#  1.68005
#  0.501309
#  1.52801
#  1.70012
#  1.99249
#  2.70608
#  2.99493
#  3.49185
#  3.50119
#  4.45992
#  4.93697
#  5.02329
#  5.04234
#  5.50739
#  5.56867

# %%
y = data[:,2]
# Out:
# 15-element Array{Float64,1}:
#   -1.6417
#   -0.977698
#    0.527711
#    1.71152
#    1.891
#   -0.463428
#   -0.443567
#   -1.27518
#   -0.6905
#   -5.51613
#   -6.0017
#   -8.36417
#   -7.92448
#  -10.7748
#  -10.9172

# %%
using Plots
plot(x, y, linetype = :scatter, leg = false)

# %%
n = 20
x = sort(rand(20)); y = rand(20)
Plots.scatter(x, y)

# %%
plot!(x,y, legend(false), title = "A sample plot")
# Out:
# UndefVarError: legend not defined

# %%
plot!(x,y, leg=false, title = "A sample plot")

# %%
newvar = rand(1:10, 4, 5)
# Out:
# 4×5 Array{Int64,2}:
#  9   9  6   3   2
#  8   9  5   1   4
#  4  10  7  10   5
#  4   6  3   9  10

# %%
diagsum = newvar(1,1) + newvar(2,2)
# Out:
# MethodError: objects of type Array{Int64,2} are not callable
# Use square brackets [] for indexing an Array.

# %%
diagsum = sum(newvar[1:2, 1:2])
# Out:
# 35

# %%
diagsum = newvar[1,1] + newvar[2,2]
# Out:
# 18

# %%
diagsum = 0
for k = 1:2
  diagsum = diagsum + newvar[k,k]
end

# %%
diagsum
# Out:
# 18

# %%
using Plots
pyplot() # Use PyPlot as a GUI (may already be the default)

x = collect(1:7)
yDash(x) = 2 - 2x + x^2/4

plot(x,yDash)

# %%
plot!(x, yDash, marker = :diamond, linewidth=2)

# %%
plot!(title = "Sample plot", leg=false)

# %%
x = [1 2 3 4 5 6]'
yDD = (x-3).^2/4
plot(x,yDD, marker = :hex, leg=false, linewidth = 2, linecolor=:black)
plot!(title="Plot for graded quiz")

# %%
x = [1 2 3 4 5 6]'
yDDD = (x-3).^2/4
plot(x,yDDD, marker = :hex, leg=false)
plot!(title="Plot for graded quiz", linewidth = 2, linecolor=:black)

# %%
x = [1, 2, 3, 4, 5, 6]
yDDDD = (x-3).^2/4
plot(x,yDDDD, marker = :hex, leg=false, linewidth = 2, linecolor=:black)
plot!(title="Plot for graded quiz")

# %%
x = [1 2 3 4 5 6]
yDDDDD = (x-3).^2/4
plot(x,yDDDDD, marker = :hex, leg=false, linewidth = 2, linecolor=:black)
plot!(title="Plot for graded quiz")

# %%
x = 1:5;
yd = x->x^2;
zd = x->x^3;

# %%
yd(x)
# Out:
# DimensionMismatch("Cannot multiply two vectors")
#
# Stacktrace:
#  [1] power_by_squaring(::UnitRange{Int64}, ::Int64) at ./intfuncs.jl:169
#  [2] (::##9#10)(::UnitRange{Int64}) at ./In[29]:2

# %%
plot(x,yd)

# %%
plot(x,zd)

# %%
x = [1, 2, 3, 4, 5, 6]
y = (x-3).^2/4
plot(x,y, marker = :hex, leg=false, linewidth = 2, linecolor=:black)
plot!(title="Plot for graded quiz")

# %%
x = [1 2 3 4 5 6]'
y = (x-3).^2/4
plot(x,y, marker = :hex, leg=false)
plot!(title="Plot for graded quiz", linewidth = 2, linecolor=:black)

# %%
x = [1 2 3 4 5 6]'
y = (x-3).^2/4
plot(x,y, marker = :hex, leg=false, linewidth = 2, linecolor=:black)
plot!(title="Plot for graded quiz")

# %%
x = [1 2 3 4 5 6]
y = (x-3).^2/4
plot(x,y, marker = :hex, leg=false, linewidth = 2, linecolor=:black)
plot!(title="Plot for graded quiz")

# %%
x = 1:5;
yd = x->x^2;
zd = x->x^3;

# %%
plot(x, [yd; zd])
